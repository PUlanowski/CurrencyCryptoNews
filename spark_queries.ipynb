# %%
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("pyspark-cnn").\
        master("spark://sparkM:7077").\
        getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-10-a760e66ff25a> in <module>
#       4         builder.\
#       5         appName("pyspark-cnn").\
# ----> 6         master("spark://sparkM:7077").\
#       7         getOrCreate()
#
# C:\Anaconda3\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     171                     for key, value in self._options.items():
#     172                         sparkConf.set(key, value)
# --> 173                     sc = SparkContext.getOrCreate(sparkConf)
#     174                     # This SparkContext may be an existing one.
#     175                     for key, value in self._options.items():
#
# C:\Anaconda3\lib\site-packages\pyspark\context.py in getOrCreate(cls, conf)
#     347         with SparkContext._lock:
#     348             if SparkContext._active_spark_context is None:
# ...
